# %%
s = "abc"

# %%
# s = "zaza"

# %%
ans = 0
for i in range(len(s)):
    alphabet_num = ord(s[i])-97
    reverse_alapha = 26-alphabet_num
    index = i+1
    
    ans += reverse_alapha*index

ans
# Out:
# 148

# %%
97-26
# Out:
# 71
