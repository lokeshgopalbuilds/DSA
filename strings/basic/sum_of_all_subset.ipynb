# %%
allowed = "abc"
words = ["a","b","c","ab","ac","bc","abc"]

# %%
allowed = "ab"
words = ["ad","bd","aaab","baa","badab"]

# %%
for i in words:
    if "".join(set(i)) in allowed:
        if any([i for i in 'ac' if i in 'abc'  ]):
            print(i)

# %%
any([i for i in 'ac' if i in 'abc'  ])
# Out:
# True
